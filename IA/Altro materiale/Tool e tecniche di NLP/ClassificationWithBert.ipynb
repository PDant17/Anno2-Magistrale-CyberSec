# %%
# !pip install transformers
# Out:
# ...
#      |████████████████████████████████| 3.4 MB 4.3 MB/s
# ...
#      |████████████████████████████████| 3.3 MB 39.7 MB/s
# ...
#      |████████████████████████████████| 61 kB 458 kB/s
# ...
#      |████████████████████████████████| 895 kB 37.1 MB/s
# ...
#      |████████████████████████████████| 596 kB 38.8 MB/s
# ...
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# **Per motivi di ricerca non ci è possibile condividere il modello su cui è stato effettuato il fine tuning del modello BERT per la classificazione di applet IFTTT. Tuttavia, vi lasciamo il link alla documentazione dove è spiegato come creare, addestrare, salvare e ricaricare un modello BERT.**
#
# **https://huggingface.co/transformers/v3.3.1/training.html**

# %%
from transformers import BertForSequenceClassification
from transformers import BertTokenizer
import torch

output_dir = '/content/drive/MyDrive/...'

# Load a trained model and vocabulary that you have fine-tuned
model = BertForSequenceClassification.from_pretrained(output_dir)
tokenizer = BertTokenizer.from_pretrained(output_dir)

# %%
# calculate the softmax of a vector
def softmax(vector):
	e = exp(vector)
	return e / e.sum()

# %%
import numpy as np
# example of a function for calculating softmax for a list of numbers
from numpy import exp

inputs = tokenizer("If there is a new email in your inbox with an attachment, then add that file to OneDrive.", return_tensors="pt")
labels = torch.tensor([1]).unsqueeze(0)  # Batch size 1
outputs = model(**inputs, labels=labels, output_attentions=True)
loss = outputs.loss
logits = outputs.logits

logits = logits.detach().cpu().numpy()

print(loss)
print(logits)
print("Label: ", np.argmax(logits, axis=1).flatten())
print("Probability: ", softmax(logits))

print("Max probability: ",softmax(logits)[0][np.argmax(softmax(logits)[0])])
# Out:
# tensor(7.8606, grad_fn=<NllLossBackward0>)
# [[ 2.4501264 -3.570245  -3.3326283  4.116427 ]]
# Label:  [3]
# Probability:  [[1.5877903e-01 3.8563734e-04 4.8907415e-04 8.4034634e-01]]
# Max probability:  0.84034634

# %%
inputs = tokenizer("If I take a new photo, then upload on Facebook as public photo.", return_tensors="pt")
labels = torch.tensor([1]).unsqueeze(0)  # Batch size 1
outputs = model(**inputs, labels=labels, output_attentions=True)
loss = outputs.loss
logits = outputs.logits

logits = logits.detach().cpu().numpy()

print(loss)
print(logits)
print("Label: ", np.argmax(logits, axis=1).flatten())
print("Probability: ", softmax(logits))

print("Max probability: ",softmax(logits)[0][np.argmax(softmax(logits)[0])])

# %%
inputs = tokenizer("Every day post your location on Facebook.", return_tensors="pt")
labels = torch.tensor([1]).unsqueeze(0)  # Batch size 1
outputs = model(**inputs, labels=labels, output_attentions=True)
loss = outputs.loss
logits = outputs.logits

logits = logits.detach().cpu().numpy()

print(loss)
print(logits)
print("Label: ", np.argmax(logits, axis=1).flatten())
print("Probability: ", softmax(logits))

print("Max probability: ",softmax(logits)[0][np.argmax(softmax(logits)[0])])

# %%
inputs = tokenizer("Save all new contacts to a specified Dropbox file. Useful for backup if you are to ever change device and want to keep contacts.", return_tensors="pt")
labels = torch.tensor([1]).unsqueeze(0)  # Batch size 1
outputs = model(**inputs, labels=labels, output_attentions=True)
loss = outputs.loss
logits = outputs.logits

logits = logits.detach().cpu().numpy()

print(loss)
print(logits)
print("Label: ", np.argmax(logits, axis=1).flatten())
print("Probability: ", softmax(logits))

print("Max probability: ",softmax(logits)[0][np.argmax(softmax(logits)[0])])
